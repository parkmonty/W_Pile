# %% [markdown]
# <a href="https://colab.research.google.com/github/parkmonty/W_Pile/blob/main/pro_week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 실습 1

# %%
import pandas as pd

# %%
df = pd.read_csv('경제활동인구.csv', encoding='cp949')
df
# Out:
#      지역  비경제활동인구  취업자  실업자
# 0   종로구       61   74    2
# 1    중구       47   70    3
# 2   용산구       71  123    4
# 3   성동구      100  150    5
# 4   광진구      119  192    7
# 5  동대문구      142  170    8

# %%
df2 = pd.DataFrame([['중랑구', 131, 207, 7]], columns = ['지역', '비경제활동인구', '취업자', '실업자'])
df = df.append(df2, ignore_index = True)
df
# Out:
# <ipython-input-58-f3b894891de0>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2, ignore_index = True)
#      지역  비경제활동인구  취업자  실업자
# 0   종로구       61   74    2
# 1    중구       47   70    3
# 2   용산구       71  123    4
# 3   성동구      100  150    5
# 4   광진구      119  192    7
# 5  동대문구      142  170    8
# 6   중랑구      131  207    7

# %%
df['경제활동인구'] = df['취업자'] + df['실업자']
df['15세 이상 인구'] = df['취업자'] + df['실업자'] + df['비경제활동인구']
df['경제활동참가율(%)'] = df['경제활동인구'] / df['15세 이상 인구'] * 100
df
# Out:
#      지역  비경제활동인구  취업자  실업자  경제활동인구  15세 이상 인구  경제활동참가율(%)
# 0   종로구       61   74    2      76        137   55.474453
# 1    중구       47   70    3      73        120   60.833333
# 2   용산구       71  123    4     127        198   64.141414
# 3   성동구      100  150    5     155        255   60.784314
# 4   광진구      119  192    7     199        318   62.578616
# 5  동대문구      142  170    8     178        320   55.625000
# 6   중랑구      131  207    7     214        345   62.028986

# %%
df[['15세 이상 인구', '경제활동인구', '취업자', '실업자', '비경제활동인구', '경제활동참가율(%)']]
# Out:
#    15세 이상 인구  경제활동인구  취업자  실업자  비경제활동인구  경제활동참가율(%)
# 0        137      76   74    2       61   55.474453
# 1        120      73   70    3       47   60.833333
# 2        198     127  123    4       71   64.141414
# 3        255     155  150    5      100   60.784314
# 4        318     199  192    7      119   62.578616
# 5        320     178  170    8      142   55.625000
# 6        345     214  207    7      131   62.028986

# %%
df[df['경제활동참가율(%)'] > 60]
# Out:
#     지역  비경제활동인구  취업자  실업자  경제활동인구  15세 이상 인구  경제활동참가율(%)
# 1   중구       47   70    3      73        120   60.833333
# 2  용산구       71  123    4     127        198   64.141414
# 3  성동구      100  150    5     155        255   60.784314
# 4  광진구      119  192    7     199        318   62.578616
# 6  중랑구      131  207    7     214        345   62.028986

# %% [markdown]
# # 이론 1

# %% [markdown]
# 1. X
# 2. O
# 3. X
# 4. X
# 5. X

# %% [markdown]
# # 실습 2

# %%
import pandas as pd

stations = [
                ["Children's Grand Park", 7, False],
                ["Achasan", 5, False],
                ["Seongsu", 2, True],
                ["Gangdong-gu Office", 8, False],
                ["Yeongdeungpo", 1, True]
            ]

# %%
# 역명, 지나가는 노선, 지상 역사가 있는지 없는지에 대한 여부
column_names = ['name', 'line', 'overground']

# %%
# 문제 1. stations과 column_names를 이용하여 DataFrame을 만들어 주세요. (1점)
df = pd.DataFrame(stations, columns = column_names)
df
# Out:
#                     name  line  overground
# 0  Children's Grand Park     7       False
# 1                Achasan     5       False
# 2                Seongsu     2        True
# 3     Gangdong-gu Office     8       False
# 4           Yeongdeungpo     1        True

# %%
# 문제 2. 'overground' 컬럼의 데이터만 출력해 주세요. (4점)
df['overground']
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# Name: overground, dtype: bool

# %%
# 문제 3. 정규표현식을 사용하여 컬럼 이름이 'e'로 끝나는 컬럼만 출력해 주세요. (5점)
import re

p = re.compile("e$")
col_list = []

for i in df:
  if p.search(i):
    col_list.append(i)

df[col_list]
# Out:
#                     name  line
# 0  Children's Grand Park     7
# 1                Achasan     5
# 2                Seongsu     2
# 3     Gangdong-gu Office     8
# 4           Yeongdeungpo     1

# %%
# 문제 4. 다음과 같이 성수(Seongsu)역에 해당하는 데이터만 'name'을 이용하여 출력해 주세요. (5점)
df[df['name'] == 'Seongsu']
# Out:
#       name  line  overground
# 2  Seongsu     2        True

# %%
# 문제 5. 5, 7, 8호선 역에 해당하는 데이터만 부등호를 이용하여 출력해 주세요. (5점)
df[df['line'] > 4]
# Out:
#                     name  line  overground
# 0  Children's Grand Park     7       False
# 1                Achasan     5       False
# 3     Gangdong-gu Office     8       False

# %%
# 문제 6. 지상 역사가 있는 역들의 데이터만 출력해 주세요. (5점)
df[df['overground'] == True]
# Out:
#            name  line  overground
# 2       Seongsu     2        True
# 4  Yeongdeungpo     1        True

# %% [markdown]
# # 이론 2

# %% [markdown]
# 1. O
# 2. X
# 3. X
# 4. X
# 5. O
